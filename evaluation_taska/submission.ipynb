# %% [markdown]
# 你这个需求本质就是：把一个 JSON 结果文件按 id-->image_id 对齐 → 提取标签 → 拼成一个 CSV（Task A 格式）。
#
# 我帮你一步步给出可直接运行的 Python 脚本，保证你能一次生成最终提交文件。

# %% [raw]
# ✅ 一、字段对应关系（很重要）
#
# 你现在有 1 个文件：
#
# 文件	     对应列
# test.json	classification-->label

# %% [raw]
# ✅ 二、标签转换规则
#
# 你的 JSON 里是：
#
# "classification": "not-misogyny"
#
# 需要转换为：
#
# classification	label
# misogyny	1
# not-misogyny	0

# %% [markdown]
# ✅ 三、完整代码（直接用）

# %% [markdown]
# qwen2.5-7b

# %%
import json
import pandas as pd

# ===== 文件路径 =====
india_path = "qwen2.5-7b/text_instruction/test.json"

# ===== 读取 JSON =====
def load_json(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

india_data = load_json(india_path)

# ===== 转换为 DataFrame =====
def to_df(data, col_name):
    df = pd.DataFrame(data)
    
    # label 映射
    df[col_name] = df["classification"].map({
        "misogyny": 1,
        "not-misogyny": 0
    })
    
    return df[["id", col_name]]

df_india = to_df(india_data, "label")

# ===== 合并（按 image_id 对齐）=====
df_india["image_id"] = df_india["id"]
df = df_india[["image_id", "label"]]

# ===== 排序（可选但推荐）=====
# df = df.sort_values(by="image_id")

# ===== 保存 =====
# output_path = "qwen2.5-7b/tamil/wangkongqiang_taska_tamil_india.csv"
output_path = "qwen2.5-7b/tamil/wangkongqiang_taska_tamil_original.csv"
df.to_csv(output_path, index=False)

print("✅ Saved to:", output_path)
print(df.head())
# Out:
# ✅ Saved to: qwen2.5-7b/tamil/wangkongqiang_taska_tamil_original.csv
#    image_id  label
# 0      1193      1
# 1       427      0
# 2      1474      0
# 3       766      0
# 4       486      1

# %% [markdown]
# mistral-latest

# %%
import json
import pandas as pd

# ===== 文件路径 =====
india_path = "mistral-latest/text_instruction/test.json"

# ===== 读取 JSON =====
def load_json(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

india_data = load_json(india_path)

# ===== 转换为 DataFrame =====
def to_df(data, col_name):
    df = pd.DataFrame(data)
    
    # label 映射
    df[col_name] = df["classification"].map({
        "misogyny": 1,
        "not-misogyny": 0
    })
    
    return df[["id", col_name]]

df_india = to_df(india_data, "label")


# ===== 合并（按 image_id 对齐）=====
df_india["image_id"] = df_india["id"]
df = df_india[["image_id", "label"]]

# ===== 排序（可选但推荐）=====
# df = df.sort_values(by="image_id")

# ===== 保存 =====
output_path = "mistral-latest/tamil/wangkongqiang_taska_tamil_original.csv"
df.to_csv(output_path, index=False)

print("✅ Saved to:", output_path)
print(df.head())
# Out:
# ✅ Saved to: mistral-latest/tamil/wangkongqiang_taska_tamil_original.csv
#    image_id  label
# 0      1193      1
# 1       427      1
# 2      1474      0
# 3       766      0
# 4       486      1

# %% [markdown]
# mistral-instruct

# %%
import json
import pandas as pd

# ===== 文件路径 =====
india_path = "mistral-instruct/text_instruction/test.json"

# ===== 读取 JSON =====
def load_json(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

india_data = load_json(india_path)

# ===== 转换为 DataFrame =====
def to_df(data, col_name):
    df = pd.DataFrame(data)
    
    # label 映射
    df[col_name] = df["classification"].map({
        "misogyny": 1,
        "not-misogyny": 0
    })
    
    return df[["id", col_name]]

df_india = to_df(india_data, "label")


# ===== 合并（按 image_id 对齐）=====
df_india["image_id"] = df_india["id"]
df = df_india[["image_id", "label"]]

# ===== 排序（可选但推荐）=====
# df = df.sort_values(by="image_id")

# ===== 保存 =====
output_path = "mistral-instruct/tamil/wangkongqiang_taska_tamil_original.csv"
df.to_csv(output_path, index=False)

print("✅ Saved to:", output_path)
print(df.head())
# Out:
# ✅ Saved to: mistral-instruct/tamil/wangkongqiang_taska_tamil_original.csv
#    image_id  label
# 0      1193      1
# 1       427      0
# 2      1474      0
# 3       766      0
# 4       486      1

# %% [markdown]
# llama3-8b

# %%
import json
import pandas as pd

# ===== 文件路径 =====
india_path = "llama3-8b/text_instruction/test.json"

# ===== 读取 JSON =====
def load_json(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

india_data = load_json(india_path)

# ===== 转换为 DataFrame =====
def to_df(data, col_name):
    df = pd.DataFrame(data)
    
    # label 映射
    df[col_name] = df["classification"].map({
        "misogyny": 1,
        "not-misogyny": 0
    })
    
    return df[["id", col_name]]

df_india = to_df(india_data, "label")

# ===== 合并（按 image_id 对齐）=====
df_india["image_id"] = df_india["id"]
df = df_india[["image_id", "label"]]

# ===== 排序（可选但推荐）=====
# df = df.sort_values(by="image_id")

# ===== 保存 =====
output_path = "llama3-8b/tamil/wangkongqiang_taska_tamil_original.csv"
df.to_csv(output_path, index=False)

print("✅ Saved to:", output_path)
print(df.head())
# Out:
# ✅ Saved to: llama3-8b/tamil/wangkongqiang_taska_tamil_original.csv
#    image_id  label
# 0      1193      0
# 1       427      0
# 2      1474      0
# 3       766      0
# 4       486      0

# %% [markdown]
# glm4-9b

# %%
import json
import pandas as pd

# ===== 文件路径 =====
india_path = "glm4-9b/text_instruction/test.json"

# ===== 读取 JSON =====
def load_json(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

india_data = load_json(india_path)

# ===== 转换为 DataFrame =====
def to_df(data, col_name):
    df = pd.DataFrame(data)
    
    # label 映射
    df[col_name] = df["classification"].map({
        "misogyny": 1,
        "not-misogyny": 0
    })
    
    return df[["id", col_name]]

df_india = to_df(india_data, "label")

# ===== 合并（按 image_id 对齐）=====
df_india["image_id"] = df_india["id"]
df = df_india[["image_id", "label"]]

# ===== 排序（可选但推荐）=====
# df = df.sort_values(by="image_id")

# ===== 保存 =====
output_path = "glm4-9b/tamil/wangkongqiang_taska_tamil_original.csv"
df.to_csv(output_path, index=False)

print("✅ Saved to:", output_path)
print(df.head())
# Out:
# ✅ Saved to: glm4-9b/tamil/wangkongqiang_taska_tamil_original.csv
#    image_id  label
# 0      1193      1
# 1       427      0
# 2      1474      0
# 3       766      0
# 4       486      0

# %% [markdown]
# gemma-7b

# %%
import json
import pandas as pd

# ===== 文件路径 =====
india_path = "gemma-7b/text_instruction/test.json"

# ===== 读取 JSON =====
def load_json(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

india_data = load_json(india_path)

# ===== 转换为 DataFrame =====
def to_df(data, col_name):
    df = pd.DataFrame(data)
    
    # label 映射
    df[col_name] = df["classification"].map({
        "misogyny": 1,
        "not-misogyny": 0
    })
    
    return df[["id", col_name]]

df_india = to_df(india_data, "label")

# ===== 合并（按 image_id 对齐）=====
df_india["image_id"] = df_india["id"]
df = df_india[["image_id", "label"]]

# ===== 排序（可选但推荐）=====
# df = df.sort_values(by="image_id")

# ===== 保存 =====
output_path = "gemma-7b/tamil/wangkongqiang_taska_tamil_original.csv"
df.to_csv(output_path, index=False)

print("✅ Saved to:", output_path)
print(df.head())
# Out:
# ✅ Saved to: gemma-7b/tamil/wangkongqiang_taska_tamil_original.csv
#    image_id  label
# 0      1193      1
# 1       427      1
# 2      1474      1
# 3       766      1
# 4       486      1

# %% [markdown]
# gemma-2b

# %%
import json
import pandas as pd

# ===== 文件路径 =====
india_path = "gemma-2b/text_instruction/test.json"

# ===== 读取 JSON =====
def load_json(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

india_data = load_json(india_path)

# ===== 转换为 DataFrame =====
def to_df(data, col_name):
    df = pd.DataFrame(data)
    
    # label 映射
    df[col_name] = df["classification"].map({
        "misogyny": 1,
        "not-misogyny": 0
    })
    
    return df[["id", col_name]]

df_india = to_df(india_data, "label")

# ===== 合并（按 image_id 对齐）=====
df_india["image_id"] = df_india["id"]
df = df_india[["image_id", "label"]]

# ===== 排序（可选但推荐）=====
# df = df.sort_values(by="image_id")

# ===== 保存 =====
output_path = "gemma-2b/tamil/wangkongqiang_taska_tamil_original.csv"
df.to_csv(output_path, index=False)

print("✅ Saved to:", output_path)
print(df.head())
# Out:
# ✅ Saved to: gemma-2b/tamil/wangkongqiang_taska_tamil_original.csv
#    image_id  label
# 0      1193      1
# 1       427      1
# 2      1474      1
# 3       766      0
# 4       486      1

# %% [markdown]
# deepseek-r1-8b

# %%
import json
import pandas as pd

# ===== 文件路径 =====
india_path = "deepseek-r1-8b/text_instruction/test.json"

# ===== 读取 JSON =====
def load_json(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

india_data = load_json(india_path)

# ===== 转换为 DataFrame =====
def to_df(data, col_name):
    df = pd.DataFrame(data)
    
    # label 映射
    df[col_name] = df["classification"].map({
        "misogyny": 1,
        "not-misogyny": 0
    })
    
    return df[["id", col_name]]

df_india = to_df(india_data, "label")

# ===== 合并（按 image_id 对齐）=====
df_india["image_id"] = df_india["id"]
df = df_india[["image_id", "label"]]

# ===== 排序（可选但推荐）=====
# df = df.sort_values(by="image_id")

# ===== 保存 =====
output_path = "deepseek-r1-8b/tamil/wangkongqiang_taska_tamil_original.csv"
df.to_csv(output_path, index=False)

print("✅ Saved to:", output_path)
print(df.head())
# Out:
# ✅ Saved to: deepseek-r1-8b/tamil/wangkongqiang_taska_tamil_original.csv
#    image_id  label
# 0      1193      1
# 1       427      0
# 2      1474      0
# 3       766      0
# 4       486      0

# %% [markdown]
# deepseek-r1-7b

# %%
import json
import pandas as pd

# ===== 文件路径 =====
india_path = "deepseek-r1-7b/text_instruction/test.json"

# ===== 读取 JSON =====
def load_json(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

india_data = load_json(india_path)

# ===== 转换为 DataFrame =====
def to_df(data, col_name):
    df = pd.DataFrame(data)
    
    # label 映射
    df[col_name] = df["classification"].map({
        "misogyny": 1,
        "not-misogyny": 0
    })
    
    return df[["id", col_name]]

df_india = to_df(india_data, "label")

# ===== 合并（按 image_id 对齐）=====
df_india["image_id"] = df_india["id"]
df = df_india[["image_id", "label"]]

# ===== 排序（可选但推荐）=====
# df = df.sort_values(by="image_id")

# ===== 保存 =====
output_path = "deepseek-r1-7b/tamil/wangkongqiang_taska_tamil_original.csv"
df.to_csv(output_path, index=False)

print("✅ Saved to:", output_path)
print(df.head())
# Out:
# ✅ Saved to: deepseek-r1-7b/tamil/wangkongqiang_taska_tamil_original.csv
#    image_id  label
# 0      1193      1
# 1       427      0
# 2      1474      0
# 3       766      0
# 4       486      0

# %% [markdown]
# deepseek-r1-1.5b

# %%
import json
import pandas as pd

# ===== 文件路径 =====
india_path = "deepseek-r1-1.5b/text_instruction/test.json"

# ===== 读取 JSON =====
def load_json(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

india_data = load_json(india_path)

# ===== 转换为 DataFrame =====
def to_df(data, col_name):
    df = pd.DataFrame(data)
    
    # label 映射
    df[col_name] = df["classification"].map({
        "misogyny": 1,
        "not-misogyny": 0
    })
    
    return df[["id", col_name]]

df_india = to_df(india_data, "label")

# ===== 合并（按 image_id 对齐）=====
df_india["image_id"] = df_india["id"]
df = df_india[["image_id", "label"]]

# ===== 排序（可选但推荐）=====
# df = df.sort_values(by="image_id")

# ===== 保存 =====
output_path = "deepseek-r1-1.5b/tamil/wangkongqiang_taska_tamil_original.csv"
df.to_csv(output_path, index=False)

print("✅ Saved to:", output_path)
print(df.head())
# Out:
# ✅ Saved to: deepseek-r1-1.5b/tamil/wangkongqiang_taska_tamil_original.csv
#    image_id  label
# 0      1193      1
# 1       427      1
# 2      1474      1
# 3       766      0
# 4       486      1
